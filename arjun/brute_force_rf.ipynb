# %%
import pandas as pd

# update path if needed
csv_path = r'test_dataset.csv'
df = pd.read_csv(csv_path)
df.head()
# Out:
#     ip  password_length  status  response_size  time_diff  attempt_count_ip  \
# 0  100               11     200           4646  57.033112                30
# 1  102               12     200           4837  46.927291                30
# 2   66                5     200           4532   0.458885               300
# 3   96               11     302           4414   6.235010                30
# 4   27                8     302           4766  35.171577                30
#
#    failed_flag  is_attack
# 0            0          0
# 1            0          0
# 2            1          1
# 3            1          0
# 4            0          0

# %%
df.info()

df.describe(include='all')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1125 entries, 0 to 1124
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ip                1125 non-null   int64
#  1   password_length   1125 non-null   int64
#  2   status            1125 non-null   int64
#  3   response_size     1125 non-null   int64
#  4   time_diff         1125 non-null   float64
#  5   attempt_count_ip  1125 non-null   int64
#  6   failed_flag       1125 non-null   int64
#  7   is_attack         1125 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 70.4 KB
#                 ip  password_length       status  response_size    time_diff  \
# count  1125.000000      1125.000000  1125.000000    1125.000000  1125.000000
# mean     54.731556         8.642667   231.370667    4680.783111    22.142463
# std      27.408355         3.107841    47.092043     234.323679    19.995324
# ...

# %%
# features: drop the label column
feature_cols = ['ip','password_length','status','response_size',
                'time_diff','attempt_count_ip','failed_flag']

X = df[feature_cols]
y = df['is_attack']

# no categorical columns needing encoding in this dataset; check for nulls
print('Null counts:\n', X.isnull().sum())
# Out:
# Null counts:
#  ip                  0
# password_length     0
# status              0
# response_size       0
# time_diff           0
# attempt_count_ip    0
# failed_flag         0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

print(f"Training samples: {X_train.shape[0]}, Test samples: {X_test.shape[0]}")
# Out:
# Training samples: 843, Test samples: 282

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

train_acc = rf.score(X_train, y_train)
print(f"Training accuracy: {train_acc:.4f}")
# Out:
# Training accuracy: 1.0000

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = rf.predict(X_test)

print("Test accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification report:\n", classification_report(y_test, y_pred))
# Out:
# Test accuracy: 1.0
#
# Confusion matrix:
#  [[188   0]
#  [  0  94]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       188
#            1       1.00      1.00      1.00        94
#
#     accuracy                           1.00       282
#    macro avg       1.00      1.00      1.00       282
# weighted avg       1.00      1.00      1.00       282

# %%
import joblib

model_path = r'd:\deepu\rf_bruteforce_model.joblib'
joblib.dump(rf, model_path)

print(f"Model saved to {model_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 import joblib
#       3 model_path = r'd:\deepu\rf_bruteforce_model.joblib'
# ----> 4 joblib.dump(rf, model_path)
#       6 print(f"Model saved to {model_path}")
#
# File d:\Arjun\WEBSHIELD\venv\Lib\site-packages\joblib\numpy_pickle.py:599, in dump(value, filename, compress, protocol)
#     597         NumpyPickler(f, protocol=protocol).dump(value)
#     598 elif is_filename:
# --> 599     with open(filename, "wb") as f:
#     600         NumpyPickler(f, protocol=protocol).dump(value)
#     601 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:\\deepu\\rf_bruteforce_model.joblib'
